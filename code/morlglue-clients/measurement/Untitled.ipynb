# %%
import pandas as pd

# %%
excel_test2 = pd.read_excel(
    "../data/bjs_5000epi/BreakableBottles-TLO_A(SafetyFirstMO)-SOFTMAY_T10-alpha0.1-lambda0.95.xls",
    sheet_name="asdf",
    engine="xlrd"
    )

# %%
excel_test2
# Out:
#                                      Episode number  R^P  R^A  R^*
# 0                             Online              1    3    0    3
# 1                             Online              2  -19   -1  -69
# 2                             Online              3 -128   -1 -278
# 3                             Online              4   -5    0   -5
# 4                             Online              5   -4    0   -4
# 5                             Online              6   -7    0   -7
# 6                             Online              7  -55   -1 -155
# 7                             Online              8  -36   -1  -86
# 8                             Online              9  -75   -1 -125
# 9                             Online             10  -35    0  -35
# 10                            Online             11   34    0   34
# 11                            Online             12 -198   -1 -298
# 12                            Online             13  -98   -1 -148
# ...

# %% [markdown]
# What about a copy saved in Excel?

# %%
excel_test2 = pd.read_excel(
    "../data/bjs_5000epi/BreakableBottles-TLO_A(SafetyFirstMO)-SOFTMAX_T10-alpha0.1-lambda0.95.xls",
    sheet_name=1,
    engine="xlrd"
    )

# %%
excel_test2
# Out:
#                                      Episode number      R^P     R^A      R^*
# 0                             Online              1    3.000  0.0000    3.000
# 1                             Online              2  -19.000 -1.0000  -69.000
# 2                             Online              3 -128.000 -1.0000 -278.000
# 3                             Online              4   -5.000  0.0000   -5.000
# 4                             Online              5   -4.000  0.0000   -4.000
# 5                             Online              6   -7.000  0.0000   -7.000
# 6                             Online              7  -55.000 -1.0000 -155.000
# 7                             Online              8  -36.000 -1.0000  -86.000
# 8                             Online              9  -75.000 -1.0000 -125.000
# 9                             Online             10  -35.000  0.0000  -35.000
# 10                            Online             11   34.000  0.0000   34.000
# ...

# %%
myxls = pd.ExcelFile("../data/bjs_5000epi/BreakableBottles-TLO_A(SafetyFirstMO)-SOFTMAY_T10-alpha0.1-lambda0.95.xls")

# %%
with myxls as x:
    excel_out = pd.read_excel(x, "Summary")

# %%
excel_out
# Out:
#          .1 AVERAGE   .2   .3  MIN   .4   .5  MAX   .6   .7  MEDIAN   .8   .9  \
# 0               R^P  R^A  R^*  R^P  R^A  R^*  R^P  R^A  R^*     R^P  R^A  R^*
# 1     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 2     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 3     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 4     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 5     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 6     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 7     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 8     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 9     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 10    4   4       4    4    4    4    4    4    4    4    4       4    4    4
# ...

# %%
myxls.parse('Summary')
# Out:
#          .1 AVERAGE   .2   .3  MIN   .4   .5  MAX   .6   .7  MEDIAN   .8   .9  \
# 0               R^P  R^A  R^*  R^P  R^A  R^*  R^P  R^A  R^*     R^P  R^A  R^*
# 1     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 2     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 3     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 4     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 5     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 6     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 7     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 8     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 9     4   4       4    4    4    4    4    4    4    4    4       4    4    4
# 10    4   4       4    4    4    4    4    4    4    4    4       4    4    4
# ...
